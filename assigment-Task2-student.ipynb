# %% [markdown]
# # IT3382 Assignment Task 2 (15 marks)
#
# ### Instructions
#
# - Complete all **four parts (Tasks 1–4)** using **this Jupyter Notebook (.ipynb)**
# - Use the following datasets provided:
#   - `HotelStatisticsMonthly.csv`
#   - `InternationalVisitorArrivalsByLengthOfStayMonthly.csv`
#   - `InternationalVisitorArrivalsByPlaceOfResidenceMonthly.csv`
# - Include all **data preparation, code, visualisations, analysis, and explanations** within the notebook
# - Use a combination of **code cells and markdown cells** to present your work clearly
# - Ensure **all code is executed** and outputs (tables, charts, results) are visible in the final notebook
# - Use appropriate **Seaborn visualisations** and provide **meaningful insights** based on your analysis
# - Ensure the notebook can run **from top to bottom without errors** and produces consistent results
#
#  **Note:** Marks will be deducted if the notebook cannot run, contains errors, or if code cells are not executed and outputs/results are not shown in the submitted saved version
#
# ### Submission Requirements
# - Submit:
#   - (i) the completed **.ipynb file (with all outputs shown)**
#   - (ii) an **exported HTML version** of the notebook for viewing

# %%
# Enter your name and Student ID here
Name:
Student ID:

# %% [markdown]
# ## Part 1: Visualization 1 (4m)
#
# Use the dataset International Visitor Arrivals by Place of Residence to analyze tourism arrival trends over time.
#
# You should
#
# - 1.1 prepare the data for analysis,
# - 1.2 create suitable Seaborn visualizations to examine overall, regional, and selected country trends,
# - 1.3 write insights on major events, seasonal patterns, and differences across regions/countries.

# %% [markdown]
# ### 1.1  prepare the data for analysis

# %%
import pandas as pd
import numpy as np

# =========================================
# TASK 1 - DATA PREPARATION
# Dataset: International Visitor Arrivals by Place of Residence
# =========================================

# %% [markdown]
# ### 1.2 create suitable Seaborn visualizations to analyse and explain your insights in 1.3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# =========================================
# TASK 1 - VISUALISATIONS
# =========================================

# -----------------------------------------
# Chart 1: Overall arrivals and regional trends
# ------------------------------------------


# -----------------------------------------
# Chart 3: Selected countries comparison
# -----------------------------------------


# -----------------------------------------
# Chart 5: Month seasonality by region
# Average arrivals by calendar month
# -----------------------------------------

# %% [markdown]
# ### 1.3 write insights on major events, seasonal patterns, and differences across regions/countries.

# %%
# your insights here. comments or markdown acceptable

# %% [markdown]
# ## Part 2: Visualization 2 (4m)
#
# Use the datasets International Visitor Arrivals by Place of Residence and International Visitors by Length of Stay to analyze how visitor volume relates to stay behaviour over time.
#
# You should:
#
# - 2.1 prepare and combine the monthly data,
# - 2.2 create suitable Seaborn visualizations to examine relationships and changes in stay behaviour,
# - 2.3 write insights on patterns, shifts, and possible tourism implications.

# %% [markdown]
# #### 2.1 prepare the data for analysis

# %%
import pandas as pd
import numpy as np

# =========================================
# TASK 2 - DATA PREPARATION
# Datasets:
# 1. International Visitor Arrivals by Place of Residence
# 2. International Visitors by Length of Stay
# =========================================

# %% [markdown]
# #### 2.1 create suitable Seaborn visualizations to analyse and explain your insights in 2.3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# =========================================
# TASK 2 - VISUALISATIONS
# =========================================

# select and implement your suitable seaborn visualizations (at least 3)

# %% [markdown]
# #### 2.3 write insights on patterns, shifts, and possible tourism implications

# %%
# your insights and implications here. comments or markdown acceptable

# %% [markdown]
# ## Part 3: Visualization 3 (4m)
#
# Investigate how visitor arrivals influence hotel performance.
#
# You should:
#
# - 1. Combine visitor arrivals + hotel statistics
# - 2. Analyse how demand affects revenue & occupancy
# - 3. Use advanced Seaborn visualisations
# - 4. Generate business-level insights

# %% [markdown]
# #### 3.1 Prepare data for visualizations

# %%
import pandas as pd

# =========================================
# TASK 3 - DATA PREPARATION
# =========================================

# -----------------------------
# A. LOAD HOTEL DATA
# -----------------------------
df_hotel_raw = pd.read_csv("HotelStatisticsMonthly.csv")


# prepare the data

# %% [markdown]
# #### 3.2 create suitable Seaborn visualizations to analyse and explain your insights in 3.3.
#
# -your visualizations should include **jointplot** and **correlation heatmap**

# %%
# Select and implement your suitable Seaborn Visualizations
import seaborn as sns
import matplotlib.pyplot as plt


# Explore reliationships 
# 1. Arrivals vs Revenue
# 2. Arrivals vs Occupancy
# 3. Correlation between key variables

# %% [markdown]
# #### 3.3 write your business insights

# %%
# your business insights here. comments or markdown acceptable

# %% [markdown]
# ## Part 4. Data Storytelling (3m)
#
# Using your analysis from Parts 1–3, develop a data-driven story that explains:
#
# How tourism demand and visitor behaviour impact hotel performance over time

# %% [markdown]
# #### 4.1 Identify 4 key findings from Task 1 - 3
# -eg. trends, relationships, behaviour

# %%
# your answer here

# %% [markdown]
# #### 4.2 Create 2x2 Visual Dashboard (consisting of 4 charts)
# - consists of at least 3 different types of Seaborn visualizations
# - charts must be properly labelled, clear and readable, and appropriate for the purpose

# %%
# your code and visualizations results

# %% [markdown]
# #### 4.3 Write your narrative (200 to 300 words) that connects your charts into a single story
# - limit 300 words
# - to include at least 2 business insights and 1 actionable recommendation

# %%
# your narrative here
